# %%
from glob import glob
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
plt.plot([pd.read_csv(filename)["acc"].values[0] for filename in glob("./*.h5")])
plt.plot([pd.read_csv(filename)["val_acc"].values[0] for filename in glob("./*.h5")], c='r')

# %%
{filename:pd.read_csv(filename)["val_acc"].values[0] for filename in glob("./*.h5")}
# Out:
# {'./model1_valid_dropout_6_Adam_1e-06_categorical_crossentropy_accuracy_acc_categorical_accuracy_0.1_32.h5': 0.1353,
#  './model1_valid_dropout_8_Adam_1e-05_categorical_crossentropy_accuracy_acc_categorical_accuracy_0.1_32.h5': 0.3032,
#  './model1_valid_Adam_1e-06_categorical_crossentropy_accuracy_acc_categorical_accuracy_0.1_32.h5': 0.4046,
#  './model1_valid_dropout_4_Adam_0.001_categorical_crossentropy_accuracy_acc_categorical_accuracy_0.1_32.h5': 0.6081,
#  './model1_valid_dropout_2_Adam_1e-06_categorical_crossentropy_accuracy_acc_categorical_accuracy_0.1_32.h5': 0.1259,
#  './model1_valid_dropout_5_Adam_0.001_categorical_crossentropy_accuracy_acc_categorical_accuracy_0.1_32.h5': 0.5492,
#  './model3_Adam_1e-05_categorical_crossentropy_accuracy_acc_categorical_accuracy_0.1_32.h5': 0.5072,
#  './model1_valid_dropout_6_Adam_0.001_categorical_crossentropy_accuracy_acc_categorical_accuracy_0.1_32.h5': 0.5598,
# ...

# %%
for filename in glob("./*.h5"):
    pd.read_csv(filename)["val_acc"].plot()
    plt.show()
